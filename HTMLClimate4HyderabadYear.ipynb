# %%
import urllib.request 
from pprint import pprint
from html_table_parser import HTMLTableParser
import pandas as pd
import csv
import string
headers={'User-Agent':'Whatever'}
def url_get_contents(url):
    req= urllib.request.Request(url=url,headers=headers)
    f=urllib.request.urlopen(req)
    return f.read()

# %%
xhtml_list=[url_get_contents('https://en.climate-data.org/asia/india/hyderabad/hyderabad-2801/t/january-1/').decode('utf-8'),url_get_contents('https://en.climate-data.org/asia/india/hyderabad/hyderabad-2801/t/february-2/').decode('utf-8'),url_get_contents('https://en.climate-data.org/asia/india/hyderabad/hyderabad-2801/t/march-3/').decode('utf-8'),url_get_contents('https://en.climate-data.org/asia/india/hyderabad/hyderabad-2801/t/april-4/').decode('utf-8'),url_get_contents('https://en.climate-data.org/asia/india/hyderabad/hyderabad-2801/t/may-5/').decode('utf-8'),url_get_contents('https://en.climate-data.org/asia/india/hyderabad/hyderabad-2801/t/june-6/').decode('utf-8'),url_get_contents('https://en.climate-data.org/asia/india/hyderabad/hyderabad-2801/t/july-7/').decode('utf-8'),url_get_contents('https://en.climate-data.org/asia/india/hyderabad/hyderabad-2801/t/august-8/').decode('utf-8'),url_get_contents('https://en.climate-data.org/asia/india/hyderabad/hyderabad-2801/t/september-9/').decode('utf-8'),url_get_contents('https://en.climate-data.org/asia/india/hyderabad/hyderabad-2801/t/october-10/').decode('utf-8'),url_get_contents('https://en.climate-data.org/asia/india/hyderabad/hyderabad-2801/t/november-11/').decode('utf-8'),url_get_contents('https://en.climate-data.org/asia/india/hyderabad/hyderabad-2801/t/december-12/').decode('utf-8')]

df=pd.DataFrame(columns=['Month','Average Temperature','Maximum Temperature','Minimum Temperature','Rain/Precipitation'])
df.to_csv('HyderabadYearlyFinalClimate.csv')
frames=[df]
for i in range(len(xhtml_list)):
    p=HTMLTableParser()
    p.feed(xhtml_list[i])
    pprint(p.tables[3])
    print("\n\nPANDAS DATAFRAME\n")
    print(pd.DataFrame(p.tables[4]))
    months_list=[]
    average_temp_list=[]
    max_temp_list=[]
    min_temp_list=[]
    rain_list=[]
    
    for j in range(1,len(p.tables[4])):
        months_list.append(p.tables[4][j][0])
        average_temp_list.append(p.tables[4][j][1])
        max_temp_list.append(p.tables[4][j][2])
        min_temp_list.append(p.tables[4][j][3])
        rain_list.append(p.tables[4][j][4])
    dfi=pd.DataFrame(list(zip(months_list, average_temp_list,max_temp_list,min_temp_list,rain_list)))
    dfi.to_csv('HyderabadYearlyFinalClimate.csv', mode = 'a', header = False)


input_file = open('HyderabadYearlyFinalClimate.csv', 'r')
output_file = open('HyderabadYearlyFinalRevised.csv', 'w')
data = csv.reader(input_file)
writer = csv.writer(output_file)
specials = 'Â°'
for line in data:
    line = [value.replace(specials, '') for value in line]
    writer.writerow(line)
input_file.close()
output_file.close()


    

#print(dffinal.head)
#with open('HyderabadYearly3Climate.csv','w',newline='') as csvfile:
#        fieldnames=['Month','Average Temperature','Maximum Temperature','Minimum Temperature','Rain/Precipitation']
#        thewriter=csv.DictWriter(csvfile,fieldnames=fieldnames)
#        thewriter.writeheader()
#        for i in range(0,len(p.tables[4])-1):
#            thewriter.writerow({'Month':dffinal.at[i,'Month'],'Average Temperature':dffinal.at[i,'Average Temperature'],'Maximum Temperature':dffinal.at[i,'Maximum Temperature'],'Minimum Temperature':dffinal.at[i,'Minimum Temperature'],'Rain/Precipitation':dffinal.at[i,'Rain/Precipitation']})
    
'''   
p=HTMLTableParser()
p.feed(xhtml)
pprint(p.tables[3])
print("\n\nPANDAS DATAFRAME\n") 
print(pd.DataFrame(p.tables[4]))
list1=[]
list2=[]
for i in range(len(p.tables[4])):
    list1.append(p.tables[4][i])
print(list1)
months_list=[]
average_temp_list=[]
max_temp_list=[]
min_temp_list=[]
rain_list=[]
for i in range(1,len(p.tables[4])):
    months_list.append(p.tables[4][i][0])
    average_temp_list.append(p.tables[4][i][1])
    max_temp_list.append(p.tables[4][i][2])
    min_temp_list.append(p.tables[4][i][3])
    rain_list.append(p.tables[4][i][4])
print(months_list)
print(average_temp_list)
print(max_temp_list)
print(min_temp_list)
print(rain_list)
df = pd.DataFrame(list(zip(months_list, average_temp_list,max_temp_list,min_temp_list,rain_list)), 
               columns =['Month', 'Average Temperature','Maximum Temperature','Minimum Temperature','Rain/Precipitation'])

print(df.head)
#df.to_csv('HyderabadJanuary.csv')
with open('HyderabadJanuaryClimate.csv','w',newline='') as csvfile:
        fieldnames=['Month','Average Temperature','Maximum Temperature','Minimum Temperature','Rain/Precipitation']
        thewriter=csv.DictWriter(csvfile,fieldnames=fieldnames)
        thewriter.writeheader()
        for i in range(0,len(p.tables[4])-1):
            thewriter.writerow({'Month':df.at[i,'Month'],'Average Temperature':df.at[i,'Average Temperature'],'Maximum Temperature':df.at[i,'Maximum Temperature'],'Minimum Temperature':df.at[i,'Minimum Temperature'],'Rain/Precipitation':df.at[i,'Rain/Precipitation']})
            
'''
# Out:
# [['',
#   'January',
#   'February',
#   'March',
#   'April',
#   'May',
#   'June',
#   'July',
#   'August',
#   'September',
#   'October',
#   'November',
#   'December'],
#  ['Avg. Temperature (°C)',
#   '22.2',
#   '24.8',
#   '28.4',
#   '31.4',
#   '33.3',
#   '29.8',
#   '26.7',
#   '26.7',
#   '26.3',
#   '25.9',
#   '23.1',
#   '21.5'],
#  ['Min. Temperature (°C)',
#   '15.5',
#   '17.8',
#   '21',
#   '24.6',
#   '26.8',
#   '24.6',
#   '22.9',
#   '22.9',
#   '22.2',
#   '20.7',
#   '17.2',
#   '14.8'],
#  ['Max. Temperature (°C)',
#   '29',
#   '31.9',
#   '35.9',
#   '38.2',
#   '39.8',
#   '35',
#   '30.6',
#   '30.5',
#   '30.5',
#   '31.1',
#   '29.1',
#   '28.3'],
#  ['Precipitation / Rainfall (mm)',
#   '4',
#   '6',
#   '12',
#   '21',
#   '32',
#   '105',
#   '156',
#   '148',
#   '175',
#   '80',
#   '20',
#   '7']]
#
#
# PANDAS DATAFRAME
#
#               0                        1                             2  \
# ...
