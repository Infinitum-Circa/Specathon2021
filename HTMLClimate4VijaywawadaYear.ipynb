# %%
import urllib.request 
from pprint import pprint
from html_table_parser import HTMLTableParser
import pandas as pd
import csv
import string
headers={'User-Agent':'Whatever'}
def url_get_contents(url):
    req= urllib.request.Request(url=url,headers=headers)
    f=urllib.request.urlopen(req)
    return f.read()

# %%
xhtml_list=[url_get_contents('https://en.climate-data.org/asia/india/andhra-pradesh/vijayawada-715084/t/january-1/').decode('utf-8'),url_get_contents('https://en.climate-data.org/asia/india/andhra-pradesh/vijayawada-715084/t/february-2/').decode('utf-8'),url_get_contents('https://en.climate-data.org/asia/india/andhra-pradesh/vijayawada-715084/t/march-3/').decode('utf-8'),url_get_contents('https://en.climate-data.org/asia/india/andhra-pradesh/vijayawada-715084/t/april-4/').decode('utf-8'),url_get_contents('https://en.climate-data.org/asia/india/andhra-pradesh/vijayawada-715084/t/may-5/').decode('utf-8'),url_get_contents('https://en.climate-data.org/asia/india/andhra-pradesh/vijayawada-715084/t/june-6/').decode('utf-8'),url_get_contents('https://en.climate-data.org/asia/india/andhra-pradesh/vijayawada-715084/t/july-7/').decode('utf-8'),url_get_contents('https://en.climate-data.org/asia/india/andhra-pradesh/vijayawada-715084/t/august-8/').decode('utf-8'),url_get_contents('https://en.climate-data.org/asia/india/andhra-pradesh/vijayawada-715084/t/september-9/').decode('utf-8'),url_get_contents('https://en.climate-data.org/asia/india/andhra-pradesh/vijayawada-715084/t/october-10/').decode('utf-8'),url_get_contents('https://en.climate-data.org/asia/india/andhra-pradesh/vijayawada-715084/t/november-11/').decode('utf-8'),url_get_contents('https://en.climate-data.org/asia/india/andhra-pradesh/vijayawada-715084/t/december-12/').decode('utf-8')]
df=pd.DataFrame(columns=['Month','Average Temperature','Maximum Temperature','Minimum Temperature','Rain/Precipitation'])
df.to_csv('VijayawadaYearlyFinalClimate.csv')
frames=[df]
for i in range(len(xhtml_list)):
    p=HTMLTableParser()
    p.feed(xhtml_list[i])
    pprint(p.tables[3])
    print("\n\nPANDAS DATAFRAME\n")
    print(pd.DataFrame(p.tables[4]))
    months_list=[]
    average_temp_list=[]
    max_temp_list=[]
    min_temp_list=[]
    rain_list=[]
    
    for j in range(1,len(p.tables[4])):
        months_list.append(p.tables[4][j][0])
        average_temp_list.append(p.tables[4][j][1])
        max_temp_list.append(p.tables[4][j][2])
        min_temp_list.append(p.tables[4][j][3])
        rain_list.append(p.tables[4][j][4])
    dfi=pd.DataFrame(list(zip(months_list, average_temp_list,max_temp_list,min_temp_list,rain_list)))
    dfi.to_csv('VijayawadaYearlyFinalClimate.csv', mode = 'a', header = False)


input_file = open('VijayawadaYearlyFinalClimate.csv', 'r')
output_file = open('VijayawadaYearlyFinalRevised.csv', 'w')
data = csv.reader(input_file)
writer = csv.writer(output_file)
specials = 'Â°'
for line in data:
    line = [value.replace(specials, '') for value in line]
    writer.writerow(line)
input_file.close()
output_file.close()
# Out:
# [['',
#   'January',
#   'February',
#   'March',
#   'April',
#   'May',
#   'June',
#   'July',
#   'August',
#   'September',
#   'October',
#   'November',
#   'December'],
#  ['Avg. Temperature (°C)',
#   '24.5',
#   '26.4',
#   '29',
#   '31.6',
#   '33.7',
#   '32.4',
#   '29.1',
#   '28.8',
#   '28.9',
#   '28',
#   '25.6',
#   '24.1'],
#  ['Min. Temperature (°C)',
#   '18.9',
#   '20.1',
#   '22.6',
#   '25.8',
#   '27.9',
#   '27.4',
#   '25.4',
#   '25.2',
#   '25.2',
#   '24.2',
#   '20.9',
#   '18.8'],
#  ['Max. Temperature (°C)',
#   '30.1',
#   '32.8',
#   '35.4',
#   '37.5',
#   '39.6',
#   '37.5',
#   '32.9',
#   '32.4',
#   '32.6',
#   '31.8',
#   '30.4',
#   '29.5'],
#  ['Precipitation / Rainfall (mm)',
#   '1',
#   '4',
#   '5',
#   '15',
#   '71',
#   '136',
#   '250',
#   '197',
#   '164',
#   '169',
#   '45',
#   '10']]
#
#
# PANDAS DATAFRAME
#
#               0                        1                             2  \
# ...
